# %% [markdown]
# # Library

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, LSTM, SimpleRNN, Dropout

# %% [markdown]
# # Data preprocessing

# %%
data = pd.DataFrame(pd.read_csv('./bike_buyers.csv'))
data.head()
# Out:
#       ID Marital Status  Gender   Income  Children        Education  \
# 0  12496        Married  Female  40000.0       1.0        Bachelors
# 1  24107        Married    Male  30000.0       3.0  Partial College
# 2  14177        Married    Male  80000.0       5.0  Partial College
# 3  24381         Single     NaN  70000.0       0.0        Bachelors
# 4  25597         Single    Male  30000.0       0.0        Bachelors
#
#        Occupation Home Owner  Cars Commute Distance   Region   Age  \
# 0  Skilled Manual        Yes   0.0        0-1 Miles   Europe  42.0
# 1        Clerical        Yes   1.0        0-1 Miles   Europe  43.0
# 2    Professional         No   2.0        2-5 Miles   Europe  60.0
# 3    Professional        Yes   1.0       5-10 Miles  Pacific  41.0
# 4        Clerical         No   0.0        0-1 Miles   Europe  36.0
#
#   Purchased Bike
# 0             No
# 1             No
# 2             No
# 3            Yes
# 4            Yes

# %% [markdown]
# ## Data cleaning

# %%
data.isna().sum()
# Out:
# ID                   0
# Marital Status       7
# Gender              11
# Income               6
# Children             8
# Education            0
# Occupation           0
# Home Owner           4
# Cars                 9
# Commute Distance     0
# Region               0
# Age                  8
# Purchased Bike       0
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Data Handle Feature

# %%
data['Marital Status'].unique()
# Out:
# array(['Married', 'Single'], dtype=object)

# %%
data['Education'].unique()
# Out:
# array(['Bachelors', 'Partial College', 'High School',
#        'Partial High School', 'Graduate Degree'], dtype=object)

# %%
data['Occupation'].unique()
# Out:
# array(['Skilled Manual', 'Clerical', 'Professional', 'Manual',
#        'Management'], dtype=object)

# %%
data['Commute Distance'].unique()
# Out:
# array(['0-1 Miles', '2-5 Miles', '1-2 Miles', '10+ Miles', '5-10 Miles'],
#       dtype=object)

# %%
data['Region'].unique()
# Out:
# array(['Europe', 'Pacific', 'North America'], dtype=object)

# %% [markdown]
# ### Handle Categorical Feature

# %%
data_dummies = pd.get_dummies(data, columns=['Marital Status', 'Education', 'Occupation', 'Commute Distance', 'Region'])
data_dummies
# Out:
#         ID  Gender    Income  Children Home Owner  Cars   Age Purchased Bike  \
# 0    12496  Female   40000.0       1.0        Yes   0.0  42.0             No
# 1    24107    Male   30000.0       3.0        Yes   1.0  43.0             No
# 2    14177    Male   80000.0       5.0         No   2.0  60.0             No
# 4    25597    Male   30000.0       0.0         No   0.0  36.0            Yes
# 5    13507  Female   10000.0       2.0        Yes   0.0  50.0             No
# ..     ...     ...       ...       ...        ...   ...   ...            ...
# 994  13466    Male   80000.0       5.0        Yes   3.0  46.0             No
# 995  23731    Male   60000.0       2.0        Yes   2.0  54.0            Yes
# 996  28672    Male   70000.0       4.0        Yes   0.0  35.0            Yes
# 998  19664    Male  100000.0       3.0         No   3.0  38.0             No
# 999  12121    Male   60000.0       3.0        Yes   2.0  53.0            Yes
#
#      Marital Status_Married  Marital Status_Single  ...  \
# 0                         1                      0  ...
# 1                         1                      0  ...
# 2                         1                      0  ...
# 4                         0                      1  ...
# 5                         1                      0  ...
# ..                      ...                    ...  ...
# 994                       1                      0  ...
# 995                       1                      0  ...
# 996                       0                      1  ...
# 998                       0                      1  ...
# 999                       0                      1  ...
#
#      Occupation_Professional  Occupation_Skilled Manual  \
# 0                          0                          1
# 1                          0                          0
# 2                          1                          0
# 4                          0                          0
# 5                          0                          0
# ..                       ...                        ...
# 994                        1                          0
# 995                        1                          0
# 996                        1                          0
# 998                        0                          0
# 999                        1                          0
#
#      Commute Distance_0-1 Miles  Commute Distance_1-2 Miles  \
# 0                             1                           0
# 1                             1                           0
# 2                             0                           0
# 4                             1                           0
# 5                             0                           1
# ..                          ...                         ...
# 994                           0                           1
# 995                           0                           0
# 996                           0                           0
# 998                           0                           1
# 999                           0                           0
#
#      Commute Distance_10+ Miles  Commute Distance_2-5 Miles  \
# 0                             0                           0
# 1                             0                           0
# 2                             0                           1
# 4                             0                           0
# 5                             0                           0
# ..                          ...                         ...
# 994                           0                           0
# 995                           0                           1
# 996                           0                           1
# 998                           0                           0
# 999                           1                           0
#
#      Commute Distance_5-10 Miles  Region_Europe  Region_North America  \
# 0                              0              1                     0
# 1                              0              1                     0
# 2                              0              1                     0
# 4                              0              1                     0
# 5                              0              1                     0
# ..                           ...            ...                   ...
# 994                            0              0                     1
# 995                            0              0                     1
# 996                            0              0                     1
# 998                            0              0                     1
# 999                            0              0                     1
#
#      Region_Pacific
# 0                 0
# 1                 0
# 2                 0
# 4                 0
# 5                 0
# ..              ...
# 994               0
# 995               0
# 996               0
# 998               0
# 999               0
#
# [952 rows x 28 columns]

# %% [markdown]
# ### Transformation

# %%
le = LabelEncoder()

name = list(data_dummies.columns)
type = data_dummies.dtypes

for i in range(len(type)):
    if type[i] == 'object' or type[i] == 'bool':
        le.fit_transform(data_dummies[name[i]])
        data_dummies[name[i]] = le.transform(data_dummies[name[i]])

data_dummies
# Out:
#         ID  Gender    Income  Children  Home Owner  Cars   Age  \
# 0    12496       0   40000.0       1.0           1   0.0  42.0
# 1    24107       1   30000.0       3.0           1   1.0  43.0
# 2    14177       1   80000.0       5.0           0   2.0  60.0
# 4    25597       1   30000.0       0.0           0   0.0  36.0
# 5    13507       0   10000.0       2.0           1   0.0  50.0
# ..     ...     ...       ...       ...         ...   ...   ...
# 994  13466       1   80000.0       5.0           1   3.0  46.0
# 995  23731       1   60000.0       2.0           1   2.0  54.0
# 996  28672       1   70000.0       4.0           1   0.0  35.0
# 998  19664       1  100000.0       3.0           0   3.0  38.0
# 999  12121       1   60000.0       3.0           1   2.0  53.0
#
#      Purchased Bike  Marital Status_Married  Marital Status_Single  ...  \
# 0                 0                       1                      0  ...
# 1                 0                       1                      0  ...
# 2                 0                       1                      0  ...
# 4                 1                       0                      1  ...
# 5                 0                       1                      0  ...
# ..              ...                     ...                    ...  ...
# 994               0                       1                      0  ...
# 995               1                       1                      0  ...
# 996               1                       0                      1  ...
# 998               0                       0                      1  ...
# 999               1                       0                      1  ...
#
#      Occupation_Professional  Occupation_Skilled Manual  \
# 0                          0                          1
# 1                          0                          0
# 2                          1                          0
# 4                          0                          0
# 5                          0                          0
# ..                       ...                        ...
# 994                        1                          0
# 995                        1                          0
# 996                        1                          0
# 998                        0                          0
# 999                        1                          0
#
#      Commute Distance_0-1 Miles  Commute Distance_1-2 Miles  \
# 0                             1                           0
# 1                             1                           0
# 2                             0                           0
# 4                             1                           0
# 5                             0                           1
# ..                          ...                         ...
# 994                           0                           1
# 995                           0                           0
# 996                           0                           0
# 998                           0                           1
# 999                           0                           0
#
#      Commute Distance_10+ Miles  Commute Distance_2-5 Miles  \
# 0                             0                           0
# 1                             0                           0
# 2                             0                           1
# 4                             0                           0
# 5                             0                           0
# ..                          ...                         ...
# 994                           0                           0
# 995                           0                           1
# 996                           0                           1
# 998                           0                           0
# 999                           1                           0
#
#      Commute Distance_5-10 Miles  Region_Europe  Region_North America  \
# 0                              0              1                     0
# 1                              0              1                     0
# 2                              0              1                     0
# 4                              0              1                     0
# 5                              0              1                     0
# ..                           ...            ...                   ...
# 994                            0              0                     1
# 995                            0              0                     1
# 996                            0              0                     1
# 998                            0              0                     1
# 999                            0              0                     1
#
#      Region_Pacific
# 0                 0
# 1                 0
# 2                 0
# 4                 0
# 5                 0
# ..              ...
# 994               0
# 995               0
# 996               0
# 998               0
# 999               0
#
# [952 rows x 28 columns]

# %% [markdown]
# ## Kiểm tra độ tương quan

# %%
plt.figure(figsize=(30, 15))
sns.heatmap(data_dummies.corr(), annot=True, cmap="Greens")
# Out:
# <Axes: >

# %% [markdown]
# ## Regularization

# %%
X = data_dummies.drop('Purchased Bike', axis=1)
y = data_dummies['Purchased Bike']

# %%
scaler = StandardScaler()
scaler.fit(X)
X_scaled = scaler.fit_transform(X)

# %%
X_scaled
# Out:
# array([[-1.4038008 , -1.00632251, -0.51585252, ...,  1.52599847,
#         -1.02123379, -0.48286708],
#        [ 0.77413366,  0.99371722, -0.8402195 , ...,  1.52599847,
#         -1.02123379, -0.48286708],
#        [-1.08848706,  0.99371722,  0.78161538, ...,  1.52599847,
#         -1.02123379, -0.48286708],
#        ...,
#        [ 1.63041398,  0.99371722,  0.45724841, ..., -0.65530865,
#          0.97920771, -0.48286708],
#        [-0.0592625 ,  0.99371722,  1.43034933, ..., -0.65530865,
#          0.97920771, -0.48286708],
#        [-1.47414146,  0.99371722,  0.13288143, ..., -0.65530865,
#          0.97920771, -0.48286708]])

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, random_state=5, test_size=0.2)

# %% [markdown]
# # RNN model

# %%
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.regularizers import l2
from keras import regularizers
from keras.optimizers import SGD

model = Sequential()
model.add(SimpleRNN(64, activation='relu', return_sequences=True, input_shape=(X_train.shape[1],1), kernel_regularizer=regularizers.L1L2(0.06)))
model.add(SimpleRNN(32, activation='relu', return_sequences=True))
model.add(SimpleRNN(16, activation='relu', return_sequences=True))
model.add(SimpleRNN(8, activation='relu', return_sequences=True))
model.add(Dropout(0.2))
model.add(SimpleRNN(1, activation='sigmoid'))

model.compile(loss="binary_crossentropy", metrics='accuracy', optimizer="adam")
earlystopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=25)

history = model.fit(X_train, y_train, epochs=100, batch_size=128, callbacks=[earlystopping], validation_data=[X_test, y_test])
# Out:
# Epoch 1/100
# 6/6 [==============================] - 2s 73ms/step - loss: 1.3354 - accuracy: 0.4770 - val_loss: 1.2986 - val_accuracy: 0.4869
# Epoch 2/100
# 6/6 [==============================] - 0s 16ms/step - loss: 1.2936 - accuracy: 0.4770 - val_loss: 1.2574 - val_accuracy: 0.4869
# Epoch 3/100
# 6/6 [==============================] - 0s 15ms/step - loss: 1.2492 - accuracy: 0.4849 - val_loss: 1.2145 - val_accuracy: 0.5445
# Epoch 4/100
# 6/6 [==============================] - 0s 17ms/step - loss: 1.2037 - accuracy: 0.5414 - val_loss: 1.1693 - val_accuracy: 0.6073
# Epoch 5/100
# 6/6 [==============================] - 0s 16ms/step - loss: 1.1618 - accuracy: 0.5729 - val_loss: 1.1478 - val_accuracy: 0.5340
# Epoch 6/100
# 6/6 [==============================] - 0s 17ms/step - loss: 1.1353 - accuracy: 0.6071 - val_loss: 1.1280 - val_accuracy: 0.5183
# Epoch 7/100
# 6/6 [==============================] - 0s 17ms/step - loss: 1.1131 - accuracy: 0.5887 - val_loss: 1.1043 - val_accuracy: 0.5707
# Epoch 8/100
# 6/6 [==============================] - 0s 16ms/step - loss: 1.0777 - accuracy: 0.6242 - val_loss: 1.0668 - val_accuracy: 0.6178
# Epoch 9/100
# 6/6 [==============================] - 0s 16ms/step - loss: 1.0578 - accuracy: 0.6176 - val_loss: 1.0551 - val_accuracy: 0.5969
# Epoch 10/100
# 6/6 [==============================] - 0s 17ms/step - loss: 1.0301 - accuracy: 0.6334 - val_loss: 1.0463 - val_accuracy: 0.5707
# Epoch 11/100
# 6/6 [==============================] - 0s 17ms/step - loss: 1.0149 - accuracy: 0.6373 - val_loss: 1.0131 - val_accuracy: 0.5707
# Epoch 12/100
# 6/6 [==============================] - 0s 16ms/step - loss: 0.9862 - accuracy: 0.6715 - val_loss: 0.9980 - val_accuracy: 0.6283
# Epoch 13/100
# 6/6 [==============================] - 0s 16ms/step - loss: 0.9606 - accuracy: 0.6846 - val_loss: 0.9789 - val_accuracy: 0.6283
# Epoch 14/100
# 6/6 [==============================] - 0s 16ms/step - loss: 0.9525 - accuracy: 0.6583 - val_loss: 0.9567 - val_accuracy: 0.6230
# Epoch 15/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.9283 - accuracy: 0.6636 - val_loss: 0.9434 - val_accuracy: 0.6230
# Epoch 16/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.9102 - accuracy: 0.6399 - val_loss: 0.9245 - val_accuracy: 0.6492
# Epoch 17/100
# 6/6 [==============================] - 0s 18ms/step - loss: 0.8980 - accuracy: 0.6689 - val_loss: 0.9062 - val_accuracy: 0.6492
# Epoch 18/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.8809 - accuracy: 0.6570 - val_loss: 0.8915 - val_accuracy: 0.6178
# Epoch 19/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.8844 - accuracy: 0.6334 - val_loss: 0.8787 - val_accuracy: 0.6492
# Epoch 20/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.8421 - accuracy: 0.6610 - val_loss: 0.8565 - val_accuracy: 0.6492
# Epoch 21/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.8169 - accuracy: 0.6781 - val_loss: 0.8512 - val_accuracy: 0.6178
# Epoch 22/100
# 6/6 [==============================] - 0s 18ms/step - loss: 0.8159 - accuracy: 0.6754 - val_loss: 0.8257 - val_accuracy: 0.6440
# Epoch 23/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.7993 - accuracy: 0.6833 - val_loss: 0.8194 - val_accuracy: 0.6387
# Epoch 24/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.7833 - accuracy: 0.6702 - val_loss: 0.8173 - val_accuracy: 0.6178
# Epoch 25/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.7593 - accuracy: 0.7030 - val_loss: 0.7991 - val_accuracy: 0.6440
# Epoch 26/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.7535 - accuracy: 0.6899 - val_loss: 0.7782 - val_accuracy: 0.6178
# Epoch 27/100
# 6/6 [==============================] - 0s 16ms/step - loss: 0.7427 - accuracy: 0.6544 - val_loss: 0.7719 - val_accuracy: 0.6440
# Epoch 28/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.7253 - accuracy: 0.6965 - val_loss: 0.7985 - val_accuracy: 0.6335
# Epoch 29/100
# 6/6 [==============================] - 0s 16ms/step - loss: 0.7150 - accuracy: 0.6886 - val_loss: 0.7614 - val_accuracy: 0.6387
# Epoch 30/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.7000 - accuracy: 0.7162 - val_loss: 0.7532 - val_accuracy: 0.6440
# Epoch 31/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.7120 - accuracy: 0.6938 - val_loss: 0.7504 - val_accuracy: 0.6335
# Epoch 32/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.7028 - accuracy: 0.6741 - val_loss: 0.7683 - val_accuracy: 0.6649
# Epoch 33/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.6931 - accuracy: 0.6965 - val_loss: 0.7483 - val_accuracy: 0.6335
# Epoch 34/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.6795 - accuracy: 0.7030 - val_loss: 0.7270 - val_accuracy: 0.6545
# Epoch 35/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.6694 - accuracy: 0.7135 - val_loss: 0.7340 - val_accuracy: 0.6649
# Epoch 36/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.6471 - accuracy: 0.7214 - val_loss: 0.7415 - val_accuracy: 0.6702
# Epoch 37/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.6579 - accuracy: 0.7306 - val_loss: 0.7455 - val_accuracy: 0.6649
# Epoch 38/100
# 6/6 [==============================] - 0s 18ms/step - loss: 0.6268 - accuracy: 0.7438 - val_loss: 0.7155 - val_accuracy: 0.6440
# Epoch 39/100
# 6/6 [==============================] - 0s 18ms/step - loss: 0.6549 - accuracy: 0.7162 - val_loss: 0.7440 - val_accuracy: 0.6230
# Epoch 40/100
# 6/6 [==============================] - 0s 18ms/step - loss: 0.6478 - accuracy: 0.7135 - val_loss: 0.7178 - val_accuracy: 0.6545
# Epoch 41/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.6317 - accuracy: 0.7240 - val_loss: 0.7057 - val_accuracy: 0.6440
# Epoch 42/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.6224 - accuracy: 0.7267 - val_loss: 0.7691 - val_accuracy: 0.6230
# Epoch 43/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.6215 - accuracy: 0.7293 - val_loss: 0.7198 - val_accuracy: 0.6911
# Epoch 44/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.6056 - accuracy: 0.7503 - val_loss: 0.7126 - val_accuracy: 0.6702
# Epoch 45/100
# 6/6 [==============================] - 0s 22ms/step - loss: 0.6020 - accuracy: 0.7477 - val_loss: 0.7046 - val_accuracy: 0.6702
# Epoch 46/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.5856 - accuracy: 0.7674 - val_loss: 0.7511 - val_accuracy: 0.6754
# Epoch 47/100
# 6/6 [==============================] - 0s 18ms/step - loss: 0.5850 - accuracy: 0.7543 - val_loss: 0.7433 - val_accuracy: 0.6859
# Epoch 48/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.5814 - accuracy: 0.7503 - val_loss: 0.7145 - val_accuracy: 0.6545
# Epoch 49/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.5906 - accuracy: 0.7582 - val_loss: 0.7012 - val_accuracy: 0.6754
# Epoch 50/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.6168 - accuracy: 0.7319 - val_loss: 0.7412 - val_accuracy: 0.6335
# Epoch 51/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.6072 - accuracy: 0.7451 - val_loss: 0.6984 - val_accuracy: 0.6492
# Epoch 52/100
# 6/6 [==============================] - 0s 18ms/step - loss: 0.6167 - accuracy: 0.7240 - val_loss: 0.7601 - val_accuracy: 0.6073
# Epoch 53/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.5852 - accuracy: 0.7530 - val_loss: 0.7290 - val_accuracy: 0.6597
# Epoch 54/100
# 6/6 [==============================] - 0s 18ms/step - loss: 0.5761 - accuracy: 0.7595 - val_loss: 0.6956 - val_accuracy: 0.6806
# Epoch 55/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.5876 - accuracy: 0.7398 - val_loss: 0.7311 - val_accuracy: 0.6597
# Epoch 56/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.5867 - accuracy: 0.7359 - val_loss: 0.7014 - val_accuracy: 0.6754
# Epoch 57/100
# 6/6 [==============================] - 0s 18ms/step - loss: 0.5678 - accuracy: 0.7727 - val_loss: 0.7461 - val_accuracy: 0.6545
# Epoch 58/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.5715 - accuracy: 0.7530 - val_loss: 0.6970 - val_accuracy: 0.6911
# Epoch 59/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.5586 - accuracy: 0.7582 - val_loss: 0.7421 - val_accuracy: 0.6702
# Epoch 60/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.5367 - accuracy: 0.7792 - val_loss: 0.7577 - val_accuracy: 0.6387
# Epoch 61/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.5246 - accuracy: 0.7898 - val_loss: 0.7079 - val_accuracy: 0.6806
# Epoch 62/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.5245 - accuracy: 0.7832 - val_loss: 0.7045 - val_accuracy: 0.6754
# Epoch 63/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.5172 - accuracy: 0.7950 - val_loss: 0.8040 - val_accuracy: 0.6387
# Epoch 64/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.5286 - accuracy: 0.7832 - val_loss: 0.8308 - val_accuracy: 0.6230
# Epoch 65/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.5171 - accuracy: 0.7806 - val_loss: 0.7976 - val_accuracy: 0.6597
# Epoch 66/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.5111 - accuracy: 0.7832 - val_loss: 0.7516 - val_accuracy: 0.6702
# Epoch 67/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.5224 - accuracy: 0.7858 - val_loss: 0.8552 - val_accuracy: 0.6335
# Epoch 68/100
# 6/6 [==============================] - 0s 18ms/step - loss: 0.4958 - accuracy: 0.8042 - val_loss: 0.8011 - val_accuracy: 0.6440
# Epoch 69/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.4908 - accuracy: 0.7950 - val_loss: 0.7819 - val_accuracy: 0.6649
# Epoch 70/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.4809 - accuracy: 0.8147 - val_loss: 0.7833 - val_accuracy: 0.6597
# Epoch 71/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.4865 - accuracy: 0.7963 - val_loss: 0.8038 - val_accuracy: 0.6754
# Epoch 72/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.4770 - accuracy: 0.8239 - val_loss: 0.8134 - val_accuracy: 0.6492
# Epoch 73/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.4826 - accuracy: 0.8239 - val_loss: 0.8602 - val_accuracy: 0.6702
# Epoch 74/100
# 6/6 [==============================] - 0s 18ms/step - loss: 0.4673 - accuracy: 0.8095 - val_loss: 0.8047 - val_accuracy: 0.6806
# Epoch 75/100
# 6/6 [==============================] - 0s 23ms/step - loss: 0.4543 - accuracy: 0.8265 - val_loss: 0.8880 - val_accuracy: 0.6649
# Epoch 76/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.4805 - accuracy: 0.8016 - val_loss: 0.8634 - val_accuracy: 0.6649
# Epoch 77/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.4729 - accuracy: 0.8121 - val_loss: 0.9675 - val_accuracy: 0.6335
# Epoch 78/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.4712 - accuracy: 0.8134 - val_loss: 0.7682 - val_accuracy: 0.7016
# Epoch 79/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.4627 - accuracy: 0.8252 - val_loss: 0.8086 - val_accuracy: 0.6806

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

plt.ylabel('accuracy')
plt.xlabel('Epoch')
plt.legend(['Training accuracy', 'Test accuracy'], loc='upper left')
plt.title('Accuracy for each epoch in training data')
plt.show()
